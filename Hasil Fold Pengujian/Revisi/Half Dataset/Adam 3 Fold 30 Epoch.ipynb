# %% [markdown]
# **Face Mask Detection**
#
# Program Machine Learning untuk mendeteksi penggunaan masker. Program dibuat menggunakan metode CNN dengan arsitektur VGG16Net dan MTCNN untuk face detection.

# %% [markdown]
# ## Mengambil Dataset dari Github

# %%
# !git clone https://github.com/georgejusen/Skripsi
# Out:
# Cloning into 'Skripsi'...
# remote: Enumerating objects: 3975, done.
# remote: Counting objects: 100% (219/219), done.
# remote: Compressing objects: 100% (119/119), done.
# remote: Total 3975 (delta 112), reused 204 (delta 97), pack-reused 3756
# Receiving objects: 100% (3975/3975), 289.32 MiB | 27.27 MiB/s, done.
# Resolving deltas: 100% (114/114), done.
# Updating files: 100% (5843/5843), done.

# %% [markdown]
# ## Mengimpor Libraries yang dibutuhkan

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import vgg16
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from imutils import paths
import matplotlib.pyplot as plt
import pathlib
import numpy as np
import argparse
import os
import itertools


print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.test.gpu_device_name()

# !nvidia-smi
# Out:
# Num GPUs Available:  1
# Thu Nov 30 05:17:54 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P0    27W /  70W |    309MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Preprocessing Datasets

# %%
# Inisialisasi nilai Initial Learning Rate, berapa banyak Epoch pelatihan, dan Batch Size
import sys
from PIL import Image
import os
INIT_LR = 1e-4
EPOCHS = 30
BS = 32
n_fold = 3

# Mengambil gambar dari dataset directory, kemudian inisialisasi data dan class gambar
print("Menginput gambar...")

# imagePaths = list(paths.list_images('dataset'))
imagePaths = list(paths.list_images("/content/Skripsi/dataset_small"))
data = []
labels = []

# Melakukan perulangan pada image paths
for imagePath in imagePaths:

    # Mengekstrak class label dari filename
    label = imagePath.split(os.path.sep)[-2]
    # Memuat input gambar (224x224) dan melakukan proses
    image = load_img(imagePath, target_size=(224, 224))
    image = img_to_array(image)
    image = preprocess_input(image)

    # Mengupdate data dan labels lists, berurutan
    data.append(image)
    labels.append(label)

# Mengkonversi data dan label ke dalam NumPy Arrays
data = np.array(data, dtype="float32")
labels = np.array(labels)

# Melakukan one-hot encoding on the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)
print("Input gambar berhasil")
# Out:
# Menginput gambar...
# Input gambar berhasil

# %% [markdown]
# ### Membuat Data Augmentation

# %%
# Membentuk training image generator untuk data augmentation
aug = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest")

# %% [markdown]
# ## Membuat Model Jaringan CNN yang sudah dipelajari sebelumnya (pre-trained convnets)

# %%
# Arsitektur jaringan VGG16Net
baseModel = tf.keras.applications.VGG16(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %% [markdown]
# ### Feature Extraction

# %%
baseModel.trainable = False
baseModel.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %% [markdown]
# ## Tahap Pembuatan Model

# %%
# Membentuk bagian head dari model yang akan ditempatkan pada base model
headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(7, 7))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(2, activation="softmax")(headModel)

# Menempatkan head model pada base model
model = Model(inputs=baseModel.input, outputs=headModel)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  average_pooling2d (Average  (None, 1, 1, 512)         0
#  Pooling2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 128)               65664
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 14780610 (56.38 MB)
# Trainable params: 65922 (257.51 KB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import numpy as np
import time
from sklearn.model_selection import KFold

kf = KFold(n_splits=n_fold, shuffle=True)

fold_accuracies = []
fold_precisions = []
fold_recalls = []
fold_f1_scores = []
all_histories = []  # Menyimpan semua riwayat pelatihan untuk setiap fold
fold_training_times = []  # Menyimpan waktu pelatihan untuk setiap fold

# Perulangan pada seluruh base model
fold = 1
for train_index, test_index in kf.split(data):
    print("Mengkompilasi model...")
    print("fold", fold)

    train_data, train_labels = data[train_index], labels[train_index]
    test_data, test_labels = data[test_index], labels[test_index]

    opt = tf.keras.optimizers.legacy.Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)

    model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])

    print("Training head model...")

    start_time = time.time()  # Catat waktu awal

    history = model.fit(
        aug.flow(train_data, train_labels, batch_size=BS),
        steps_per_epoch=len(train_data) // BS,
        validation_data=(test_data, test_labels),
        validation_steps=len(test_data) // BS,
        epochs=EPOCHS)

    end_time = time.time()  # Catat waktu akhir
    training_time = end_time - start_time
    fold_training_times.append(training_time)

    all_histories.append(history)

    loss, accuracy = model.evaluate(test_data, test_labels, verbose=0)
    fold_accuracies.append(accuracy)

    # Prediksi dan hitung f1 score, presisi, dan recall
    predictions = model.predict(test_data)
    predictions = np.round(predictions)
    f1 = f1_score(test_labels, predictions, average='macro')
    precision = precision_score(test_labels, predictions, average='macro')
    recall = recall_score(test_labels, predictions, average='macro')
    fold_f1_scores.append(f1)
    fold_precisions.append(precision)
    fold_recalls.append(recall)

    # Plotting untuk setiap fold
    plt.figure(figsize=(12, 8))

    plt.plot(history.history['accuracy'])
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_accuracy'])
    plt.plot(history.history['val_loss'])

    plt.title(f'Model Metrics - Fold {fold}')
    plt.ylabel('Value')
    plt.xlabel('Epoch')
    plt.legend(['Accuracy', 'Loss', 'Validation Accuracy', 'Validation Loss'], loc='upper left')

    plt.show()

    print(f"Training time for Fold {fold}: {training_time:.2f} seconds")

    fold += 1

# Print fold accuracies, f1 scores, precisions, and recalls
for fold, accuracy, f1, precision, recall, training_time in zip(range(1, fold+1), fold_accuracies, fold_f1_scores, fold_precisions, fold_recalls, fold_training_times):
    print(f"Fold {fold} - Accuracy: {accuracy:.4f}, F1 Score: {f1:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}")
    print(f"Training time for Fold {fold}: {training_time:.2f} seconds")
# Out:
# Mengkompilasi model...
# fold 1
# Training head model...
# Epoch 1/30
# 33/33 [==============================] - 37s 763ms/step - loss: 0.7255 - accuracy: 0.5329 - val_loss: 0.6312 - val_accuracy: 0.8858
# Epoch 2/30
# 33/33 [==============================] - 16s 499ms/step - loss: 0.6616 - accuracy: 0.6074 - val_loss: 0.5760 - val_accuracy: 0.9345
# Epoch 3/30
# 33/33 [==============================] - 16s 500ms/step - loss: 0.6005 - accuracy: 0.7166 - val_loss: 0.5171 - val_accuracy: 0.9700
# Epoch 4/30
# 33/33 [==============================] - 23s 685ms/step - loss: 0.5465 - accuracy: 0.7882 - val_loss: 0.4706 - val_accuracy: 0.9607
# Epoch 5/30
# 33/33 [==============================] - 19s 586ms/step - loss: 0.5055 - accuracy: 0.8346 - val_loss: 0.4273 - val_accuracy: 0.9682
# Epoch 6/30
# 33/33 [==============================] - 19s 586ms/step - loss: 0.4617 - accuracy: 0.8849 - val_loss: 0.3939 - val_accuracy: 0.9532
# Epoch 7/30
# 33/33 [==============================] - 17s 504ms/step - loss: 0.4236 - accuracy: 0.9014 - val_loss: 0.3568 - val_accuracy: 0.9532
# Epoch 8/30
# 33/33 [==============================] - 19s 583ms/step - loss: 0.3872 - accuracy: 0.9284 - val_loss: 0.3248 - val_accuracy: 0.9551
# Epoch 9/30
# 33/33 [==============================] - 19s 586ms/step - loss: 0.3597 - accuracy: 0.9323 - val_loss: 0.2897 - val_accuracy: 0.9700
# Epoch 10/30
# 33/33 [==============================] - 19s 586ms/step - loss: 0.3336 - accuracy: 0.9304 - val_loss: 0.2700 - val_accuracy: 0.9625
# Epoch 11/30
# 33/33 [==============================] - 19s 584ms/step - loss: 0.2977 - accuracy: 0.9545 - val_loss: 0.2506 - val_accuracy: 0.9607
# Epoch 12/30
# 33/33 [==============================] - 19s 586ms/step - loss: 0.2898 - accuracy: 0.9526 - val_loss: 0.2321 - val_accuracy: 0.9644
# Epoch 13/30
# 33/33 [==============================] - 19s 580ms/step - loss: 0.2614 - accuracy: 0.9536 - val_loss: 0.2097 - val_accuracy: 0.9738
# Epoch 14/30
# 33/33 [==============================] - 17s 506ms/step - loss: 0.2501 - accuracy: 0.9545 - val_loss: 0.2007 - val_accuracy: 0.9682
# Epoch 15/30
# 33/33 [==============================] - 17s 510ms/step - loss: 0.2334 - accuracy: 0.9613 - val_loss: 0.1818 - val_accuracy: 0.9757
# Epoch 16/30
# 33/33 [==============================] - 19s 587ms/step - loss: 0.2168 - accuracy: 0.9700 - val_loss: 0.1731 - val_accuracy: 0.9757
# Epoch 17/30
# 33/33 [==============================] - 19s 582ms/step - loss: 0.2096 - accuracy: 0.9545 - val_loss: 0.1635 - val_accuracy: 0.9757
# Epoch 18/30
# 33/33 [==============================] - 19s 583ms/step - loss: 0.2019 - accuracy: 0.9671 - val_loss: 0.1563 - val_accuracy: 0.9738
# Epoch 19/30
# 33/33 [==============================] - 19s 583ms/step - loss: 0.1864 - accuracy: 0.9710 - val_loss: 0.1465 - val_accuracy: 0.9775
# Epoch 20/30
# 33/33 [==============================] - 19s 585ms/step - loss: 0.1763 - accuracy: 0.9662 - val_loss: 0.1394 - val_accuracy: 0.9757
# Epoch 21/30
# 33/33 [==============================] - 19s 564ms/step - loss: 0.1653 - accuracy: 0.9691 - val_loss: 0.1288 - val_accuracy: 0.9757
# Epoch 22/30
# 33/33 [==============================] - 19s 592ms/step - loss: 0.1644 - accuracy: 0.9662 - val_loss: 0.1228 - val_accuracy: 0.9757
# Epoch 23/30
# 33/33 [==============================] - 19s 587ms/step - loss: 0.1534 - accuracy: 0.9671 - val_loss: 0.1163 - val_accuracy: 0.9794
# Epoch 24/30
# 33/33 [==============================] - 19s 588ms/step - loss: 0.1474 - accuracy: 0.9700 - val_loss: 0.1116 - val_accuracy: 0.9813
# Epoch 25/30
# 33/33 [==============================] - 19s 588ms/step - loss: 0.1418 - accuracy: 0.9739 - val_loss: 0.1127 - val_accuracy: 0.9775
# Epoch 26/30
# 33/33 [==============================] - 19s 579ms/step - loss: 0.1389 - accuracy: 0.9778 - val_loss: 0.1057 - val_accuracy: 0.9794
# Epoch 27/30
# 33/33 [==============================] - 17s 509ms/step - loss: 0.1315 - accuracy: 0.9778 - val_loss: 0.0998 - val_accuracy: 0.9813
# Epoch 28/30
# 33/33 [==============================] - 16s 481ms/step - loss: 0.1262 - accuracy: 0.9758 - val_loss: 0.1008 - val_accuracy: 0.9757
# Epoch 29/30
# 33/33 [==============================] - 19s 567ms/step - loss: 0.1291 - accuracy: 0.9768 - val_loss: 0.0956 - val_accuracy: 0.9775
# Epoch 30/30
# 33/33 [==============================] - 17s 501ms/step - loss: 0.1135 - accuracy: 0.9768 - val_loss: 0.0910 - val_accuracy: 0.9831
# 17/17 [==============================] - 2s 126ms/step
# Training time for Fold 1: 603.12 seconds
# Mengkompilasi model...
# fold 2
# Training head model...
# Epoch 1/30
# 33/33 [==============================] - 21s 625ms/step - loss: 0.1203 - accuracy: 0.9691 - val_loss: 0.0783 - val_accuracy: 0.9850
# Epoch 2/30
# 33/33 [==============================] - 19s 593ms/step - loss: 0.1140 - accuracy: 0.9739 - val_loss: 0.0769 - val_accuracy: 0.9831
# Epoch 3/30
# 33/33 [==============================] - 19s 583ms/step - loss: 0.1163 - accuracy: 0.9700 - val_loss: 0.0715 - val_accuracy: 0.9850
# Epoch 4/30
# 33/33 [==============================] - 19s 568ms/step - loss: 0.1005 - accuracy: 0.9797 - val_loss: 0.0702 - val_accuracy: 0.9850
# Epoch 5/30
# 33/33 [==============================] - 19s 587ms/step - loss: 0.0981 - accuracy: 0.9787 - val_loss: 0.0713 - val_accuracy: 0.9812
# Epoch 6/30
# 33/33 [==============================] - 19s 582ms/step - loss: 0.0886 - accuracy: 0.9836 - val_loss: 0.0654 - val_accuracy: 0.9850
# Epoch 7/30
# 33/33 [==============================] - 19s 588ms/step - loss: 0.0979 - accuracy: 0.9768 - val_loss: 0.0635 - val_accuracy: 0.9850
# Epoch 8/30
# 33/33 [==============================] - 19s 594ms/step - loss: 0.0993 - accuracy: 0.9710 - val_loss: 0.0611 - val_accuracy: 0.9850
# Epoch 9/30
# 33/33 [==============================] - 19s 587ms/step - loss: 0.0899 - accuracy: 0.9729 - val_loss: 0.0617 - val_accuracy: 0.9850
# Epoch 10/30
# 33/33 [==============================] - 19s 583ms/step - loss: 0.0893 - accuracy: 0.9768 - val_loss: 0.0576 - val_accuracy: 0.9850
# Epoch 11/30
# 33/33 [==============================] - 16s 488ms/step - loss: 0.0885 - accuracy: 0.9797 - val_loss: 0.0548 - val_accuracy: 0.9850
# Epoch 12/30
# 33/33 [==============================] - 17s 515ms/step - loss: 0.0856 - accuracy: 0.9787 - val_loss: 0.0548 - val_accuracy: 0.9869
# Epoch 13/30
# 33/33 [==============================] - 19s 585ms/step - loss: 0.0700 - accuracy: 0.9884 - val_loss: 0.0552 - val_accuracy: 0.9850
# Epoch 14/30
# 33/33 [==============================] - 17s 510ms/step - loss: 0.0844 - accuracy: 0.9782 - val_loss: 0.0514 - val_accuracy: 0.9850
# Epoch 15/30
# 33/33 [==============================] - 17s 507ms/step - loss: 0.0751 - accuracy: 0.9836 - val_loss: 0.0501 - val_accuracy: 0.9850
# Epoch 16/30
# 33/33 [==============================] - 19s 591ms/step - loss: 0.0706 - accuracy: 0.9797 - val_loss: 0.0502 - val_accuracy: 0.9869
# Epoch 17/30
# 33/33 [==============================] - 19s 582ms/step - loss: 0.0781 - accuracy: 0.9797 - val_loss: 0.0491 - val_accuracy: 0.9869
# Epoch 18/30
# 33/33 [==============================] - 20s 604ms/step - loss: 0.0769 - accuracy: 0.9768 - val_loss: 0.0477 - val_accuracy: 0.9850
# Epoch 19/30
# 33/33 [==============================] - 19s 588ms/step - loss: 0.0689 - accuracy: 0.9845 - val_loss: 0.0497 - val_accuracy: 0.9850
# Epoch 20/30
# 33/33 [==============================] - 19s 584ms/step - loss: 0.0686 - accuracy: 0.9826 - val_loss: 0.0470 - val_accuracy: 0.9869
# Epoch 21/30
# 33/33 [==============================] - 19s 588ms/step - loss: 0.0679 - accuracy: 0.9778 - val_loss: 0.0457 - val_accuracy: 0.9869
# Epoch 22/30
# 33/33 [==============================] - 17s 509ms/step - loss: 0.0704 - accuracy: 0.9758 - val_loss: 0.0449 - val_accuracy: 0.9869
# Epoch 23/30
# 33/33 [==============================] - 17s 518ms/step - loss: 0.0689 - accuracy: 0.9826 - val_loss: 0.0435 - val_accuracy: 0.9850
# Epoch 24/30
# 33/33 [==============================] - 19s 585ms/step - loss: 0.0677 - accuracy: 0.9826 - val_loss: 0.0444 - val_accuracy: 0.9869
# Epoch 25/30
# 33/33 [==============================] - 19s 583ms/step - loss: 0.0681 - accuracy: 0.9797 - val_loss: 0.0417 - val_accuracy: 0.9869
# Epoch 26/30
# 33/33 [==============================] - 19s 586ms/step - loss: 0.0622 - accuracy: 0.9836 - val_loss: 0.0418 - val_accuracy: 0.9850
# Epoch 27/30
# 33/33 [==============================] - 19s 587ms/step - loss: 0.0619 - accuracy: 0.9836 - val_loss: 0.0423 - val_accuracy: 0.9869
# Epoch 28/30
# 33/33 [==============================] - 17s 511ms/step - loss: 0.0657 - accuracy: 0.9816 - val_loss: 0.0416 - val_accuracy: 0.9869
# Epoch 29/30
# 33/33 [==============================] - 19s 561ms/step - loss: 0.0641 - accuracy: 0.9826 - val_loss: 0.0407 - val_accuracy: 0.9850
# Epoch 30/30
# 33/33 [==============================] - 19s 585ms/step - loss: 0.0565 - accuracy: 0.9826 - val_loss: 0.0395 - val_accuracy: 0.9869
# 17/17 [==============================] - 2s 128ms/step
# Training time for Fold 2: 582.73 seconds
# Mengkompilasi model...
# fold 3
# Training head model...
# Epoch 1/30
# 33/33 [==============================] - 20s 600ms/step - loss: 0.0757 - accuracy: 0.9778 - val_loss: 0.0411 - val_accuracy: 0.9850
# Epoch 2/30
# 33/33 [==============================] - 19s 566ms/step - loss: 0.0570 - accuracy: 0.9855 - val_loss: 0.0382 - val_accuracy: 0.9869
# Epoch 3/30
# 33/33 [==============================] - 19s 594ms/step - loss: 0.0572 - accuracy: 0.9816 - val_loss: 0.0411 - val_accuracy: 0.9869
# Epoch 4/30
# 33/33 [==============================] - 17s 505ms/step - loss: 0.0611 - accuracy: 0.9807 - val_loss: 0.0387 - val_accuracy: 0.9869
# Epoch 5/30
# 33/33 [==============================] - 17s 517ms/step - loss: 0.0504 - accuracy: 0.9903 - val_loss: 0.0394 - val_accuracy: 0.9869
# Epoch 6/30
# 33/33 [==============================] - 19s 588ms/step - loss: 0.0568 - accuracy: 0.9807 - val_loss: 0.0373 - val_accuracy: 0.9869
# Epoch 7/30
# 33/33 [==============================] - 19s 592ms/step - loss: 0.0608 - accuracy: 0.9807 - val_loss: 0.0379 - val_accuracy: 0.9869
# Epoch 8/30
# 33/33 [==============================] - 19s 581ms/step - loss: 0.0589 - accuracy: 0.9797 - val_loss: 0.0354 - val_accuracy: 0.9869
# Epoch 9/30
# 33/33 [==============================] - 19s 581ms/step - loss: 0.0557 - accuracy: 0.9845 - val_loss: 0.0361 - val_accuracy: 0.9869
# Epoch 10/30
# 33/33 [==============================] - 19s 588ms/step - loss: 0.0631 - accuracy: 0.9845 - val_loss: 0.0377 - val_accuracy: 0.9869
# Epoch 11/30
# 33/33 [==============================] - 19s 582ms/step - loss: 0.0571 - accuracy: 0.9836 - val_loss: 0.0376 - val_accuracy: 0.9869
# Epoch 12/30
# 33/33 [==============================] - 19s 570ms/step - loss: 0.0522 - accuracy: 0.9845 - val_loss: 0.0364 - val_accuracy: 0.9869
# Epoch 13/30
# 33/33 [==============================] - 19s 585ms/step - loss: 0.0561 - accuracy: 0.9826 - val_loss: 0.0361 - val_accuracy: 0.9869
# Epoch 14/30
# 33/33 [==============================] - 19s 593ms/step - loss: 0.0474 - accuracy: 0.9874 - val_loss: 0.0380 - val_accuracy: 0.9869
# Epoch 15/30
# 33/33 [==============================] - 19s 587ms/step - loss: 0.0521 - accuracy: 0.9855 - val_loss: 0.0363 - val_accuracy: 0.9869
# Epoch 16/30
# 33/33 [==============================] - 19s 590ms/step - loss: 0.0454 - accuracy: 0.9884 - val_loss: 0.0395 - val_accuracy: 0.9869
# Epoch 17/30
# 33/33 [==============================] - 19s 583ms/step - loss: 0.0520 - accuracy: 0.9884 - val_loss: 0.0357 - val_accuracy: 0.9869
# Epoch 18/30
# 33/33 [==============================] - 19s 589ms/step - loss: 0.0528 - accuracy: 0.9836 - val_loss: 0.0345 - val_accuracy: 0.9869
# Epoch 19/30
# 33/33 [==============================] - 19s 579ms/step - loss: 0.0453 - accuracy: 0.9874 - val_loss: 0.0351 - val_accuracy: 0.9869
# Epoch 20/30
# 33/33 [==============================] - 17s 508ms/step - loss: 0.0450 - accuracy: 0.9894 - val_loss: 0.0349 - val_accuracy: 0.9869
# Epoch 21/30
# 33/33 [==============================] - 19s 583ms/step - loss: 0.0509 - accuracy: 0.9845 - val_loss: 0.0374 - val_accuracy: 0.9869
# Epoch 22/30
# 33/33 [==============================] - 17s 502ms/step - loss: 0.0492 - accuracy: 0.9894 - val_loss: 0.0353 - val_accuracy: 0.9869
# Epoch 23/30
# 33/33 [==============================] - 19s 581ms/step - loss: 0.0513 - accuracy: 0.9797 - val_loss: 0.0366 - val_accuracy: 0.9869
# Epoch 24/30
# 33/33 [==============================] - 19s 588ms/step - loss: 0.0406 - accuracy: 0.9903 - val_loss: 0.0341 - val_accuracy: 0.9869
# Epoch 25/30
# 33/33 [==============================] - 19s 582ms/step - loss: 0.0508 - accuracy: 0.9855 - val_loss: 0.0353 - val_accuracy: 0.9869
# Epoch 26/30
# 33/33 [==============================] - 17s 496ms/step - loss: 0.0621 - accuracy: 0.9778 - val_loss: 0.0345 - val_accuracy: 0.9869
# Epoch 27/30
# 33/33 [==============================] - 19s 580ms/step - loss: 0.0500 - accuracy: 0.9865 - val_loss: 0.0359 - val_accuracy: 0.9869
# Epoch 28/30
# 33/33 [==============================] - 17s 504ms/step - loss: 0.0495 - accuracy: 0.9855 - val_loss: 0.0360 - val_accuracy: 0.9869
# Epoch 29/30
# 33/33 [==============================] - 19s 583ms/step - loss: 0.0388 - accuracy: 0.9865 - val_loss: 0.0344 - val_accuracy: 0.9869
# Epoch 30/30
# 33/33 [==============================] - 19s 586ms/step - loss: 0.0421 - accuracy: 0.9874 - val_loss: 0.0351 - val_accuracy: 0.9869
# 17/17 [==============================] - 2s 126ms/step
# Training time for Fold 3: 589.55 seconds
# Fold 1 - Accuracy: 0.9831, F1 Score: 0.9831, Precision: 0.9828, Recall: 0.9840
# Training time for Fold 1: 603.12 seconds
# Fold 2 - Accuracy: 0.9869, F1 Score: 0.9868, Precision: 0.9872, Recall: 0.9865
# Training time for Fold 2: 582.73 seconds
# Fold 3 - Accuracy: 0.9869, F1 Score: 0.9869, Precision: 0.9870, Recall: 0.9869
# Training time for Fold 3: 589.55 seconds

# %% [markdown]
# ## Evaluasi Jaringan

# %%
from sklearn.metrics import confusion_matrix
# Hitung confusion matrix
conf_matrix = confusion_matrix(test_labels.argmax(axis=1), predictions.argmax(axis=1))

# Tampilkan confusion matrix
print(f"Confusion Matrix for Fold {fold}:\n{conf_matrix}")

# Atau, Anda juga dapat menggunakan library seaborn untuk tampilan yang lebih baik
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=lb.classes_, yticklabels=lb.classes_)
plt.title(f'Confusion Matrix - Fold {fold}')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Confusion Matrix for Fold 3:
# [[261   6]
#  [  1 265]]

# %%
# Convert model to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TensorFlow Lite model to a file
tflite_model_filename = 'model.tflite'
with open(tflite_model_filename, 'wb') as f:
    f.write(tflite_model)

print(f"TensorFlow Lite model saved to {tflite_model_filename}")
# Out:
# TensorFlow Lite model saved to model.tflite
