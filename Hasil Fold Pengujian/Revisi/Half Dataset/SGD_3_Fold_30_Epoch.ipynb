# %% [markdown]
# **Face Mask Detection**
#
# Program Machine Learning untuk mendeteksi penggunaan masker. Program dibuat menggunakan metode CNN dengan arsitektur VGG16Net dan MTCNN untuk face detection.

# %% [markdown]
# ## Mengambil Dataset dari Github

# %%
# !git clone https://github.com/georgejusen/Skripsi
# Out:
# Cloning into 'Skripsi'...
# remote: Enumerating objects: 3975, done.
# remote: Counting objects: 100% (219/219), done.
# remote: Compressing objects: 100% (119/119), done.
# remote: Total 3975 (delta 112), reused 204 (delta 97), pack-reused 3756
# Receiving objects: 100% (3975/3975), 289.32 MiB | 37.72 MiB/s, done.
# Resolving deltas: 100% (114/114), done.
# Updating files: 100% (5843/5843), done.

# %% [markdown]
# ## Mengimpor Libraries yang dibutuhkan

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import vgg16
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from imutils import paths
import matplotlib.pyplot as plt
import pathlib
import numpy as np
import argparse
import os
import itertools


print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.test.gpu_device_name()

# !nvidia-smi
# Out:
# Num GPUs Available:  1
# Sat Dec  2 03:49:51 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   53C    P0    28W /  70W |    309MiB / 15360MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Preprocessing Datasets

# %%
# Inisialisasi nilai Initial Learning Rate, berapa banyak Epoch pelatihan, dan Batch Size
import sys
from PIL import Image
import os
INIT_LR = 1e-4
EPOCHS = 30
BS = 32
n_fold = 3

# Mengambil gambar dari dataset directory, kemudian inisialisasi data dan class gambar
print("Menginput gambar...")

# imagePaths = list(paths.list_images('dataset'))
imagePaths = list(paths.list_images("/content/Skripsi/dataset_small"))
data = []
labels = []

# Melakukan perulangan pada image paths
for imagePath in imagePaths:

    # Mengekstrak class label dari filename
    label = imagePath.split(os.path.sep)[-2]
    # Memuat input gambar (224x224) dan melakukan proses
    image = load_img(imagePath, target_size=(224, 224))
    image = img_to_array(image)
    image = preprocess_input(image)

    # Mengupdate data dan labels lists, berurutan
    data.append(image)
    labels.append(label)

# Mengkonversi data dan label ke dalam NumPy Arrays
data = np.array(data, dtype="float32")
labels = np.array(labels)

# Melakukan one-hot encoding on the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)
print("Input gambar berhasil")
# Out:
# Menginput gambar...
# Input gambar berhasil

# %% [markdown]
# ### Membuat Data Augmentation

# %%
# Membentuk training image generator untuk data augmentation
aug = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest")

# %% [markdown]
# ## Membuat Model Jaringan CNN yang sudah dipelajari sebelumnya (pre-trained convnets)

# %%
# Arsitektur jaringan VGG16Net
baseModel = tf.keras.applications.VGG16(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %% [markdown]
# ### Feature Extraction

# %%
baseModel.trainable = False
baseModel.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %% [markdown]
# ## Tahap Pembuatan Model

# %%
# Membentuk bagian head dari model yang akan ditempatkan pada base model
headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(7, 7))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(2, activation="softmax")(headModel)

# Menempatkan head model pada base model
model = Model(inputs=baseModel.input, outputs=headModel)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  average_pooling2d (Average  (None, 1, 1, 512)         0
#  Pooling2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 128)               65664
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 14780610 (56.38 MB)
# Trainable params: 65922 (257.51 KB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import numpy as np
import time
from sklearn.model_selection import KFold

kf = KFold(n_splits=n_fold, shuffle=True)

fold_accuracies = []
fold_precisions = []
fold_recalls = []
fold_f1_scores = []
all_histories = []  # Menyimpan semua riwayat pelatihan untuk setiap fold
fold_training_times = []  # Menyimpan waktu pelatihan untuk setiap fold

# Perulangan pada seluruh base model
fold = 1
for train_index, test_index in kf.split(data):
    print("Mengkompilasi model...")
    print("fold", fold)

    train_data, train_labels = data[train_index], labels[train_index]
    test_data, test_labels = data[test_index], labels[test_index]

    opt = tf.keras.optimizers.legacy.SGD(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)

    model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])

    print("Training head model...")

    start_time = time.time()  # Catat waktu awal

    history = model.fit(
        aug.flow(train_data, train_labels, batch_size=BS),
        steps_per_epoch=len(train_data) // BS,
        validation_data=(test_data, test_labels),
        validation_steps=len(test_data) // BS,
        epochs=EPOCHS)

    end_time = time.time()  # Catat waktu akhir
    training_time = end_time - start_time
    fold_training_times.append(training_time)

    all_histories.append(history)

    loss, accuracy = model.evaluate(test_data, test_labels, verbose=0)
    fold_accuracies.append(accuracy)

    # Prediksi dan hitung f1 score, presisi, dan recall
    predictions = model.predict(test_data)
    predictions = np.round(predictions)
    f1 = f1_score(test_labels, predictions, average='macro')
    precision = precision_score(test_labels, predictions, average='macro')
    recall = recall_score(test_labels, predictions, average='macro')
    fold_f1_scores.append(f1)
    fold_precisions.append(precision)
    fold_recalls.append(recall)

    # Plotting untuk setiap fold
    plt.figure(figsize=(12, 8))

    plt.plot(history.history['accuracy'])
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_accuracy'])
    plt.plot(history.history['val_loss'])

    plt.title(f'Model Metrics - Fold {fold}')
    plt.ylabel('Value')
    plt.xlabel('Epoch')
    plt.legend(['Accuracy', 'Loss', 'Validation Accuracy', 'Validation Loss'], loc='upper left')

    plt.show()

    print(f"Training time for Fold {fold}: {training_time:.2f} seconds")

    # Membuat plot untuk distribusi data fold
    plt.figure(figsize=(8, 6))
    plt.hist([train_index, test_index], bins=10, label=['Train', 'Test'])
    plt.title(f'Data Distribution for Fold {fold}')
    plt.xlabel('Data Index')
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()

    fold += 1

# Print fold accuracies, f1 scores, precisions, and recalls
for fold, accuracy, f1, precision, recall, training_time in zip(range(1, fold+1), fold_accuracies, fold_f1_scores, fold_precisions, fold_recalls, fold_training_times):
    print(f"Fold {fold} - Accuracy: {accuracy:.4f}, F1 Score: {f1:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}")
    print(f"Training time for Fold {fold}: {training_time:.2f} seconds")
# Out:
# Mengkompilasi model...
# fold 1
# Training head model...
# Epoch 1/30
# 33/33 [==============================] - 38s 782ms/step - loss: 0.7856 - accuracy: 0.5203 - val_loss: 0.7269 - val_accuracy: 0.5655
# Epoch 2/30
# 33/33 [==============================] - 19s 535ms/step - loss: 0.7772 - accuracy: 0.5116 - val_loss: 0.7221 - val_accuracy: 0.5712
# Epoch 3/30
# 33/33 [==============================] - 17s 526ms/step - loss: 0.7614 - accuracy: 0.5271 - val_loss: 0.7179 - val_accuracy: 0.5655
# Epoch 4/30
# 33/33 [==============================] - 17s 510ms/step - loss: 0.7769 - accuracy: 0.4865 - val_loss: 0.7143 - val_accuracy: 0.5655
# Epoch 5/30
# 33/33 [==============================] - 19s 594ms/step - loss: 0.7597 - accuracy: 0.5290 - val_loss: 0.7109 - val_accuracy: 0.5674
# Epoch 6/30
# 33/33 [==============================] - 19s 589ms/step - loss: 0.7774 - accuracy: 0.4990 - val_loss: 0.7083 - val_accuracy: 0.5599
# Epoch 7/30
# 33/33 [==============================] - 19s 591ms/step - loss: 0.7580 - accuracy: 0.5193 - val_loss: 0.7058 - val_accuracy: 0.5581
# Epoch 8/30
# 33/33 [==============================] - 17s 526ms/step - loss: 0.7648 - accuracy: 0.5097 - val_loss: 0.7037 - val_accuracy: 0.5599
# Epoch 9/30
# 33/33 [==============================] - 17s 526ms/step - loss: 0.7724 - accuracy: 0.4971 - val_loss: 0.7017 - val_accuracy: 0.5524
# Epoch 10/30
# 33/33 [==============================] - 19s 586ms/step - loss: 0.7668 - accuracy: 0.5029 - val_loss: 0.7001 - val_accuracy: 0.5562
# Epoch 11/30
# 33/33 [==============================] - 17s 513ms/step - loss: 0.7542 - accuracy: 0.5135 - val_loss: 0.6985 - val_accuracy: 0.5581
# Epoch 12/30
# 33/33 [==============================] - 19s 584ms/step - loss: 0.7546 - accuracy: 0.5058 - val_loss: 0.6971 - val_accuracy: 0.5581
# Epoch 13/30
# 33/33 [==============================] - 17s 515ms/step - loss: 0.7559 - accuracy: 0.5097 - val_loss: 0.6959 - val_accuracy: 0.5468
# Epoch 14/30
# 33/33 [==============================] - 17s 517ms/step - loss: 0.7465 - accuracy: 0.5280 - val_loss: 0.6949 - val_accuracy: 0.5562
# Epoch 15/30
# 33/33 [==============================] - 19s 587ms/step - loss: 0.7350 - accuracy: 0.5513 - val_loss: 0.6939 - val_accuracy: 0.5637
# Epoch 16/30
# 33/33 [==============================] - 20s 595ms/step - loss: 0.7443 - accuracy: 0.5145 - val_loss: 0.6929 - val_accuracy: 0.5693
# Epoch 17/30
# 33/33 [==============================] - 17s 506ms/step - loss: 0.7396 - accuracy: 0.5358 - val_loss: 0.6920 - val_accuracy: 0.5787
# Epoch 18/30
# 33/33 [==============================] - 17s 510ms/step - loss: 0.7508 - accuracy: 0.5203 - val_loss: 0.6912 - val_accuracy: 0.5768
# Epoch 19/30
# 33/33 [==============================] - 19s 583ms/step - loss: 0.7412 - accuracy: 0.5242 - val_loss: 0.6904 - val_accuracy: 0.5843
# Epoch 20/30
# 33/33 [==============================] - 19s 587ms/step - loss: 0.7356 - accuracy: 0.5222 - val_loss: 0.6897 - val_accuracy: 0.5918
# Epoch 21/30
# 33/33 [==============================] - 17s 514ms/step - loss: 0.7329 - accuracy: 0.5329 - val_loss: 0.6891 - val_accuracy: 0.5955
# Epoch 22/30
# 33/33 [==============================] - 19s 582ms/step - loss: 0.7447 - accuracy: 0.5155 - val_loss: 0.6884 - val_accuracy: 0.6067
# Epoch 23/30
# 33/33 [==============================] - 20s 597ms/step - loss: 0.7374 - accuracy: 0.5164 - val_loss: 0.6878 - val_accuracy: 0.6105
# Epoch 24/30
# 33/33 [==============================] - 19s 582ms/step - loss: 0.7426 - accuracy: 0.5174 - val_loss: 0.6872 - val_accuracy: 0.6180
# Epoch 25/30
# 33/33 [==============================] - 19s 587ms/step - loss: 0.7395 - accuracy: 0.5309 - val_loss: 0.6866 - val_accuracy: 0.6180
# Epoch 26/30
# 33/33 [==============================] - 19s 573ms/step - loss: 0.7480 - accuracy: 0.5203 - val_loss: 0.6861 - val_accuracy: 0.6255
# Epoch 27/30
# 33/33 [==============================] - 17s 510ms/step - loss: 0.7378 - accuracy: 0.5358 - val_loss: 0.6856 - val_accuracy: 0.6292
# Epoch 28/30
# 33/33 [==============================] - 17s 510ms/step - loss: 0.7464 - accuracy: 0.5087 - val_loss: 0.6851 - val_accuracy: 0.6236
# Epoch 29/30
# 33/33 [==============================] - 16s 488ms/step - loss: 0.7188 - accuracy: 0.5822 - val_loss: 0.6846 - val_accuracy: 0.6236
# Epoch 30/30
# 33/33 [==============================] - 17s 506ms/step - loss: 0.7288 - accuracy: 0.5513 - val_loss: 0.6841 - val_accuracy: 0.6161
# 17/17 [==============================] - 2s 133ms/step
# Training time for Fold 1: 603.68 seconds
# Mengkompilasi model...
# fold 2
# Training head model...
# Epoch 1/30
# 33/33 [==============================] - 28s 813ms/step - loss: 0.7408 - accuracy: 0.5256 - val_loss: 0.6830 - val_accuracy: 0.6454
# Epoch 2/30
# 33/33 [==============================] - 16s 486ms/step - loss: 0.7336 - accuracy: 0.5362 - val_loss: 0.6825 - val_accuracy: 0.6529
# Epoch 3/30
# 33/33 [==============================] - 19s 584ms/step - loss: 0.7335 - accuracy: 0.5208 - val_loss: 0.6821 - val_accuracy: 0.6548
# Epoch 4/30
# 33/33 [==============================] - 19s 582ms/step - loss: 0.7321 - accuracy: 0.5362 - val_loss: 0.6816 - val_accuracy: 0.6585
# Epoch 5/30
# 33/33 [==============================] - 19s 582ms/step - loss: 0.7299 - accuracy: 0.5507 - val_loss: 0.6812 - val_accuracy: 0.6679
# Epoch 6/30
# 33/33 [==============================] - 20s 598ms/step - loss: 0.7231 - accuracy: 0.5700 - val_loss: 0.6807 - val_accuracy: 0.6735
# Epoch 7/30
# 33/33 [==============================] - 17s 508ms/step - loss: 0.7317 - accuracy: 0.5353 - val_loss: 0.6803 - val_accuracy: 0.6754
# Epoch 8/30
# 33/33 [==============================] - 17s 506ms/step - loss: 0.7235 - accuracy: 0.5527 - val_loss: 0.6799 - val_accuracy: 0.6829
# Epoch 9/30
# 33/33 [==============================] - 19s 585ms/step - loss: 0.7424 - accuracy: 0.5150 - val_loss: 0.6794 - val_accuracy: 0.6886
# Epoch 10/30
# 33/33 [==============================] - 19s 578ms/step - loss: 0.7357 - accuracy: 0.5217 - val_loss: 0.6790 - val_accuracy: 0.6979
# Epoch 11/30
# 33/33 [==============================] - 19s 591ms/step - loss: 0.7237 - accuracy: 0.5478 - val_loss: 0.6786 - val_accuracy: 0.7017
# Epoch 12/30
# 33/33 [==============================] - 19s 585ms/step - loss: 0.7290 - accuracy: 0.5372 - val_loss: 0.6781 - val_accuracy: 0.7092
# Epoch 13/30
# 33/33 [==============================] - 17s 520ms/step - loss: 0.7296 - accuracy: 0.5304 - val_loss: 0.6777 - val_accuracy: 0.7092
# Epoch 14/30
# 33/33 [==============================] - 17s 513ms/step - loss: 0.7334 - accuracy: 0.5304 - val_loss: 0.6773 - val_accuracy: 0.7129
# Epoch 15/30
# 33/33 [==============================] - 17s 516ms/step - loss: 0.7348 - accuracy: 0.5266 - val_loss: 0.6769 - val_accuracy: 0.7092
# Epoch 16/30
# 33/33 [==============================] - 19s 588ms/step - loss: 0.7255 - accuracy: 0.5546 - val_loss: 0.6765 - val_accuracy: 0.7261
# Epoch 17/30
# 33/33 [==============================] - 19s 587ms/step - loss: 0.7261 - accuracy: 0.5401 - val_loss: 0.6761 - val_accuracy: 0.7298
# Epoch 18/30
# 33/33 [==============================] - 17s 513ms/step - loss: 0.7145 - accuracy: 0.5634 - val_loss: 0.6757 - val_accuracy: 0.7355
# Epoch 19/30
# 33/33 [==============================] - 19s 586ms/step - loss: 0.7289 - accuracy: 0.5333 - val_loss: 0.6752 - val_accuracy: 0.7411
# Epoch 20/30
# 33/33 [==============================] - 17s 508ms/step - loss: 0.7180 - accuracy: 0.5652 - val_loss: 0.6748 - val_accuracy: 0.7542
# Epoch 21/30
# 33/33 [==============================] - 19s 594ms/step - loss: 0.7157 - accuracy: 0.5652 - val_loss: 0.6744 - val_accuracy: 0.7580
# Epoch 22/30
# 33/33 [==============================] - 19s 586ms/step - loss: 0.7289 - accuracy: 0.5469 - val_loss: 0.6740 - val_accuracy: 0.7580
# Epoch 23/30
# 33/33 [==============================] - 17s 509ms/step - loss: 0.7199 - accuracy: 0.5662 - val_loss: 0.6736 - val_accuracy: 0.7617
# Epoch 24/30
# 33/33 [==============================] - 17s 507ms/step - loss: 0.7148 - accuracy: 0.5498 - val_loss: 0.6732 - val_accuracy: 0.7655
# Epoch 25/30
# 33/33 [==============================] - 19s 585ms/step - loss: 0.7223 - accuracy: 0.5440 - val_loss: 0.6728 - val_accuracy: 0.7749
# Epoch 26/30
# 33/33 [==============================] - 19s 583ms/step - loss: 0.7223 - accuracy: 0.5604 - val_loss: 0.6725 - val_accuracy: 0.7786
# Epoch 27/30
# 33/33 [==============================] - 19s 588ms/step - loss: 0.7257 - accuracy: 0.5217 - val_loss: 0.6720 - val_accuracy: 0.7842
# Epoch 28/30
# 33/33 [==============================] - 20s 597ms/step - loss: 0.7171 - accuracy: 0.5604 - val_loss: 0.6716 - val_accuracy: 0.7880
# Epoch 29/30
# 33/33 [==============================] - 17s 517ms/step - loss: 0.7067 - accuracy: 0.5681 - val_loss: 0.6713 - val_accuracy: 0.7936
# Epoch 30/30
# 33/33 [==============================] - 19s 584ms/step - loss: 0.7201 - accuracy: 0.5546 - val_loss: 0.6709 - val_accuracy: 0.7955
# 17/17 [==============================] - 2s 132ms/step
# Training time for Fold 2: 600.09 seconds
# Mengkompilasi model...
# fold 3
# Training head model...
# Epoch 1/30
# 33/33 [==============================] - 19s 535ms/step - loss: 0.7174 - accuracy: 0.5594 - val_loss: 0.6667 - val_accuracy: 0.8349
# Epoch 2/30
# 33/33 [==============================] - 19s 585ms/step - loss: 0.7096 - accuracy: 0.5700 - val_loss: 0.6663 - val_accuracy: 0.8424
# Epoch 3/30
# 33/33 [==============================] - 17s 504ms/step - loss: 0.7171 - accuracy: 0.5285 - val_loss: 0.6659 - val_accuracy: 0.8424
# Epoch 4/30
# 33/33 [==============================] - 19s 579ms/step - loss: 0.6999 - accuracy: 0.5874 - val_loss: 0.6655 - val_accuracy: 0.8499
# Epoch 5/30
# 33/33 [==============================] - 19s 594ms/step - loss: 0.7154 - accuracy: 0.5633 - val_loss: 0.6652 - val_accuracy: 0.8518
# Epoch 6/30
# 33/33 [==============================] - 19s 580ms/step - loss: 0.7174 - accuracy: 0.5517 - val_loss: 0.6648 - val_accuracy: 0.8537
# Epoch 7/30
# 33/33 [==============================] - 19s 581ms/step - loss: 0.7115 - accuracy: 0.5575 - val_loss: 0.6644 - val_accuracy: 0.8555
# Epoch 8/30
# 33/33 [==============================] - 19s 585ms/step - loss: 0.7095 - accuracy: 0.5585 - val_loss: 0.6641 - val_accuracy: 0.8555
# Epoch 9/30
# 33/33 [==============================] - 19s 568ms/step - loss: 0.7156 - accuracy: 0.5527 - val_loss: 0.6638 - val_accuracy: 0.8593
# Epoch 10/30
# 33/33 [==============================] - 19s 583ms/step - loss: 0.7122 - accuracy: 0.5614 - val_loss: 0.6634 - val_accuracy: 0.8630
# Epoch 11/30
# 33/33 [==============================] - 17s 505ms/step - loss: 0.7189 - accuracy: 0.5594 - val_loss: 0.6630 - val_accuracy: 0.8630
# Epoch 12/30
# 33/33 [==============================] - 20s 596ms/step - loss: 0.7102 - accuracy: 0.5748 - val_loss: 0.6627 - val_accuracy: 0.8649
# Epoch 13/30
# 33/33 [==============================] - 19s 580ms/step - loss: 0.7190 - accuracy: 0.5362 - val_loss: 0.6623 - val_accuracy: 0.8649
# Epoch 14/30
# 33/33 [==============================] - 17s 503ms/step - loss: 0.7116 - accuracy: 0.5710 - val_loss: 0.6619 - val_accuracy: 0.8649
# Epoch 15/30
# 33/33 [==============================] - 17s 511ms/step - loss: 0.7061 - accuracy: 0.5662 - val_loss: 0.6616 - val_accuracy: 0.8630
# Epoch 16/30
# 33/33 [==============================] - 19s 583ms/step - loss: 0.7083 - accuracy: 0.5652 - val_loss: 0.6612 - val_accuracy: 0.8630
# Epoch 17/30
# 33/33 [==============================] - 19s 559ms/step - loss: 0.7063 - accuracy: 0.5749 - val_loss: 0.6609 - val_accuracy: 0.8630
# Epoch 18/30
# 33/33 [==============================] - 19s 587ms/step - loss: 0.7005 - accuracy: 0.5942 - val_loss: 0.6605 - val_accuracy: 0.8630
# Epoch 19/30
# 33/33 [==============================] - 19s 588ms/step - loss: 0.7139 - accuracy: 0.5594 - val_loss: 0.6602 - val_accuracy: 0.8630
# Epoch 20/30
# 33/33 [==============================] - 17s 517ms/step - loss: 0.7045 - accuracy: 0.5710 - val_loss: 0.6598 - val_accuracy: 0.8668
# Epoch 21/30
# 33/33 [==============================] - 19s 594ms/step - loss: 0.7113 - accuracy: 0.5578 - val_loss: 0.6595 - val_accuracy: 0.8687
# Epoch 22/30
# 33/33 [==============================] - 19s 586ms/step - loss: 0.7085 - accuracy: 0.5787 - val_loss: 0.6591 - val_accuracy: 0.8687
# Epoch 23/30
# 33/33 [==============================] - 19s 581ms/step - loss: 0.6961 - accuracy: 0.5961 - val_loss: 0.6588 - val_accuracy: 0.8687
# Epoch 24/30
# 33/33 [==============================] - 19s 583ms/step - loss: 0.7037 - accuracy: 0.5643 - val_loss: 0.6584 - val_accuracy: 0.8705
# Epoch 25/30
# 33/33 [==============================] - 19s 586ms/step - loss: 0.7011 - accuracy: 0.5923 - val_loss: 0.6581 - val_accuracy: 0.8705
# Epoch 26/30
# 33/33 [==============================] - 19s 583ms/step - loss: 0.7022 - accuracy: 0.5720 - val_loss: 0.6577 - val_accuracy: 0.8762
# Epoch 27/30
# 33/33 [==============================] - 19s 561ms/step - loss: 0.7121 - accuracy: 0.5488 - val_loss: 0.6574 - val_accuracy: 0.8762
# Epoch 28/30
# 33/33 [==============================] - 19s 588ms/step - loss: 0.7077 - accuracy: 0.5836 - val_loss: 0.6570 - val_accuracy: 0.8780
# Epoch 29/30
# 33/33 [==============================] - 17s 510ms/step - loss: 0.7046 - accuracy: 0.5826 - val_loss: 0.6567 - val_accuracy: 0.8799
# Epoch 30/30
# 33/33 [==============================] - 19s 585ms/step - loss: 0.7120 - accuracy: 0.5700 - val_loss: 0.6564 - val_accuracy: 0.8837
# 17/17 [==============================] - 2s 131ms/step
# Training time for Fold 3: 577.15 seconds
# Fold 1 - Accuracy: 0.6161, F1 Score: 0.6157, Precision: 0.6174, Recall: 0.6167
# Training time for Fold 1: 603.68 seconds
# Fold 2 - Accuracy: 0.7955, F1 Score: 0.7953, Precision: 0.7965, Recall: 0.7953
# Training time for Fold 2: 600.09 seconds
# Fold 3 - Accuracy: 0.8837, F1 Score: 0.8835, Precision: 0.8885, Recall: 0.8849
# Training time for Fold 3: 577.15 seconds

# %% [markdown]
# ## Evaluasi Jaringan

# %%
from sklearn.metrics import confusion_matrix
# Hitung confusion matrix
conf_matrix = confusion_matrix(test_labels.argmax(axis=1), predictions.argmax(axis=1))

# Tampilkan confusion matrix
print(f"Confusion Matrix for Fold {fold}:\n{conf_matrix}")

# Atau, Anda juga dapat menggunakan library seaborn untuk tampilan yang lebih baik
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=lb.classes_, yticklabels=lb.classes_)
plt.title(f'Confusion Matrix - Fold {fold}')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Confusion Matrix for Fold 3:
# [[225  47]
#  [ 15 246]]

# %%
# Convert model to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TensorFlow Lite model to a file
tflite_model_filename = 'model.tflite'
with open(tflite_model_filename, 'wb') as f:
    f.write(tflite_model)

print(f"TensorFlow Lite model saved to {tflite_model_filename}")
# Out:
# TensorFlow Lite model saved to model.tflite
