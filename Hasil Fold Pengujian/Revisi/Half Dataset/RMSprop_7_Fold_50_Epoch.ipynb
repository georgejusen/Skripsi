# %% [markdown]
# **Face Mask Detection**
#
# Program Machine Learning untuk mendeteksi penggunaan masker. Program dibuat menggunakan metode CNN dengan arsitektur VGG16Net dan MTCNN untuk face detection.

# %% [markdown]
# ## Mengambil Dataset dari Github

# %%
# !git clone https://github.com/georgejusen/Skripsi
# Out:
# Cloning into 'Skripsi'...
# remote: Enumerating objects: 3988, done.
# remote: Counting objects: 100% (232/232), done.
# remote: Compressing objects: 100% (122/122), done.
# remote: Total 3988 (delta 123), reused 216 (delta 107), pack-reused 3756
# Receiving objects: 100% (3988/3988), 295.11 MiB | 15.35 MiB/s, done.
# Resolving deltas: 100% (125/125), done.
# Updating files: 100% (5845/5845), done.

# %% [markdown]
# ## Mengimpor Libraries yang dibutuhkan

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import vgg16
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from imutils import paths
import matplotlib.pyplot as plt
import pathlib
import numpy as np
import argparse
import os
import itertools


print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.test.gpu_device_name()

# !nvidia-smi
# Out:
# Num GPUs Available:  1
# Mon Dec  4 16:12:16 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P0    26W /  70W |    309MiB / 15360MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Preprocessing Datasets

# %%
# Inisialisasi nilai Initial Learning Rate, berapa banyak Epoch pelatihan, dan Batch Size
import sys
from PIL import Image
import os
INIT_LR = 1e-4
EPOCHS = 50
BS = 32
n_fold = 7

# Mengambil gambar dari dataset directory, kemudian inisialisasi data dan class gambar
print("Menginput gambar...")

# imagePaths = list(paths.list_images('dataset'))
imagePaths = list(paths.list_images("/content/Skripsi/dataset_small"))
data = []
labels = []

# Melakukan perulangan pada image paths
for imagePath in imagePaths:

    # Mengekstrak class label dari filename
    label = imagePath.split(os.path.sep)[-2]
    # Memuat input gambar (224x224) dan melakukan proses
    image = load_img(imagePath, target_size=(224, 224))
    image = img_to_array(image)
    image = preprocess_input(image)

    # Mengupdate data dan labels lists, berurutan
    data.append(image)
    labels.append(label)

# Mengkonversi data dan label ke dalam NumPy Arrays
data = np.array(data, dtype="float32")
labels = np.array(labels)

# Melakukan one-hot encoding on the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)
print("Input gambar berhasil")
# Out:
# Menginput gambar...
# Input gambar berhasil

# %% [markdown]
# ### Membuat Data Augmentation

# %%
# Membentuk training image generator untuk data augmentation
aug = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest")

# %% [markdown]
# ## Membuat Model Jaringan CNN yang sudah dipelajari sebelumnya (pre-trained convnets)

# %%
# Arsitektur jaringan VGG16Net
baseModel = tf.keras.applications.VGG16(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step

# %% [markdown]
# ### Feature Extraction

# %%
baseModel.trainable = False
baseModel.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %% [markdown]
# ## Tahap Pembuatan Model

# %%
# Membentuk bagian head dari model yang akan ditempatkan pada base model
headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(7, 7))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(2, activation="softmax")(headModel)

# Menempatkan head model pada base model
model = Model(inputs=baseModel.input, outputs=headModel)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  average_pooling2d (Average  (None, 1, 1, 512)         0
#  Pooling2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 128)               65664
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 14780610 (56.38 MB)
# Trainable params: 65922 (257.51 KB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import numpy as np
import time
from sklearn.model_selection import KFold

kf = KFold(n_splits=n_fold, shuffle=True)

fold_accuracies = []
fold_precisions = []
fold_recalls = []
fold_f1_scores = []
all_histories = []  # Menyimpan semua riwayat pelatihan untuk setiap fold
fold_training_times = []  # Menyimpan waktu pelatihan untuk setiap fold

# Perulangan pada seluruh base model
fold = 1
for train_index, test_index in kf.split(data):
    print("Mengkompilasi model...")
    print("fold", fold)

    train_data, train_labels = data[train_index], labels[train_index]
    test_data, test_labels = data[test_index], labels[test_index]

    opt = tf.keras.optimizers.legacy.RMSprop(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)

    model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])

    print("Training head model...")

    start_time = time.time()  # Catat waktu awal

    history = model.fit(
        aug.flow(train_data, train_labels, batch_size=BS),
        steps_per_epoch=len(train_data) // BS,
        validation_data=(test_data, test_labels),
        validation_steps=len(test_data) // BS,
        epochs=EPOCHS)

    end_time = time.time()  # Catat waktu akhir
    training_time = end_time - start_time
    fold_training_times.append(training_time)

    all_histories.append(history)

    loss, accuracy = model.evaluate(test_data, test_labels, verbose=0)
    fold_accuracies.append(accuracy)

    # Prediksi dan hitung f1 score, presisi, dan recall
    predictions = model.predict(test_data)
    predictions = np.round(predictions)
    f1 = f1_score(test_labels, predictions, average='macro')
    precision = precision_score(test_labels, predictions, average='macro')
    recall = recall_score(test_labels, predictions, average='macro')
    fold_f1_scores.append(f1)
    fold_precisions.append(precision)
    fold_recalls.append(recall)

    # Plotting untuk setiap fold
    plt.figure(figsize=(12, 8))

    plt.plot(history.history['accuracy'])
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_accuracy'])
    plt.plot(history.history['val_loss'])

    plt.title(f'Model Metrics - Fold {fold}')
    plt.ylabel('Value')
    plt.xlabel('Epoch')
    plt.legend(['Accuracy', 'Loss', 'Validation Accuracy', 'Validation Loss'], loc='upper left')

    plt.show()

    print(f"Training time for Fold {fold}: {training_time:.2f} seconds")

    # Membuat plot untuk distribusi data fold
    plt.figure(figsize=(8, 6))
    plt.hist([train_index, test_index], bins=10, label=['Train', 'Test'])
    plt.title(f'Data Distribution for Fold {fold}')
    plt.xlabel('Data Index')
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()

    fold += 1

# Print fold accuracies, f1 scores, precisions, and recalls
for fold, accuracy, f1, precision, recall, training_time in zip(range(1, fold+1), fold_accuracies, fold_f1_scores, fold_precisions, fold_recalls, fold_training_times):
    print(f"Fold {fold} - Accuracy: {accuracy:.4f}, F1 Score: {f1:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}")
    print(f"Training time for Fold {fold}: {training_time:.2f} seconds")
# Out:
# Mengkompilasi model...
# fold 1
# Training head model...
# Epoch 1/50
# 42/42 [==============================] - 39s 619ms/step - loss: 0.7347 - accuracy: 0.5414 - val_loss: 0.6377 - val_accuracy: 0.8821
# Epoch 2/50
# 42/42 [==============================] - 19s 438ms/step - loss: 0.6503 - accuracy: 0.6774 - val_loss: 0.5767 - val_accuracy: 0.9389
# Epoch 3/50
# 42/42 [==============================] - 20s 484ms/step - loss: 0.5846 - accuracy: 0.7812 - val_loss: 0.5219 - val_accuracy: 0.9520
# Epoch 4/50
# 42/42 [==============================] - 19s 452ms/step - loss: 0.5217 - accuracy: 0.8753 - val_loss: 0.4686 - val_accuracy: 0.9563
# Epoch 5/50
# 42/42 [==============================] - 18s 423ms/step - loss: 0.4780 - accuracy: 0.8954 - val_loss: 0.4226 - val_accuracy: 0.9563
# Epoch 6/50
# 42/42 [==============================] - 18s 435ms/step - loss: 0.4287 - accuracy: 0.9328 - val_loss: 0.3786 - val_accuracy: 0.9563
# Epoch 7/50
# 42/42 [==============================] - 18s 438ms/step - loss: 0.3941 - accuracy: 0.9380 - val_loss: 0.3372 - val_accuracy: 0.9563
# Epoch 8/50
# 42/42 [==============================] - 18s 433ms/step - loss: 0.3443 - accuracy: 0.9544 - val_loss: 0.2995 - val_accuracy: 0.9563
# Epoch 9/50
# 42/42 [==============================] - 19s 439ms/step - loss: 0.3147 - accuracy: 0.9432 - val_loss: 0.2686 - val_accuracy: 0.9563
# Epoch 10/50
# 42/42 [==============================] - 18s 429ms/step - loss: 0.2823 - accuracy: 0.9597 - val_loss: 0.2418 - val_accuracy: 0.9563
# Epoch 11/50
# 42/42 [==============================] - 18s 432ms/step - loss: 0.2632 - accuracy: 0.9613 - val_loss: 0.2161 - val_accuracy: 0.9563
# Epoch 12/50
# 42/42 [==============================] - 20s 462ms/step - loss: 0.2394 - accuracy: 0.9567 - val_loss: 0.1974 - val_accuracy: 0.9563
# Epoch 13/50
# 42/42 [==============================] - 18s 435ms/step - loss: 0.2231 - accuracy: 0.9612 - val_loss: 0.1787 - val_accuracy: 0.9563
# Epoch 14/50
# 42/42 [==============================] - 19s 448ms/step - loss: 0.1946 - accuracy: 0.9671 - val_loss: 0.1634 - val_accuracy: 0.9563
# Epoch 15/50
# 42/42 [==============================] - 18s 434ms/step - loss: 0.1820 - accuracy: 0.9671 - val_loss: 0.1485 - val_accuracy: 0.9607
# Epoch 16/50
# 42/42 [==============================] - 18s 431ms/step - loss: 0.1702 - accuracy: 0.9701 - val_loss: 0.1398 - val_accuracy: 0.9607
# Epoch 17/50
# 42/42 [==============================] - 19s 442ms/step - loss: 0
50
# 42/42 [==============================] - 19s 448ms/step - loss: 0.0266 - accuracy: 0.9933 - val_loss: 0.0097 - val_accuracy: 0.9956
# Epoch 37/50
# 42/42 [==============================] - 19s 443ms/step - loss: 0.0188 - accuracy: 0.9918 - val_loss: 0.0109 - val_accuracy: 0.9956
# Epoch 38/50
# 42/42 [==============================] - 19s 447ms/step - loss: 0.0316 - accuracy: 0.9910 - val_loss: 0.0115 - val_accuracy: 0.9956
# Epoch 39/50
# 42/42 [==============================] - 21s 498ms/step - loss: 0.0216 - accuracy: 0.9925 - val_loss: 0.0098 - val_accuracy: 0.9956
# Epoch 40/50
# 42/42 [==============================] - 19s 445ms/step - loss: 0.0303 - accuracy: 0.9925 - val_loss: 0.0094 - val_accuracy: 0.9956
# Epoch 41/50
# 42/42 [==============================] - 19s 461ms/step - loss: 0.0311 - accuracy: 0.9881 - val_loss: 0.0104 - val_accuracy: 0.9956
# Epoch 42/50
# 42/42 [==============================] - 19s 449ms/step - loss: 0.0234 - accuracy: 0.9933 - val_loss: 0.0122 - val_accuracy: 0.9956
# Epoch 43/50
# 42/42 [==============================] - 19s 448ms/step - loss: 0.0241 - accuracy: 0.9925 - val_loss: 0.0099 - val_accuracy: 0.9956
# Epoch 44/50
# 42/42 [==============================] - 20s 468ms/step - loss: 0.0214 - accuracy: 0.9918 - val_loss: 0.0097 - val_accuracy: 0.9956
# Epoch 45/50
# 42/42 [==============================] - 18s 437ms/step - loss: 0.0202 - accuracy: 0.9955 - val_loss: 0.0126 - val_accuracy: 0.9956
# Epoch 46/50
# 42/42 [==============================] - 20s 482ms/step - loss: 0.0250 - accuracy: 0.9903 - val_loss: 0.0131 - val_accuracy: 0.9956
# Epoch 47/50
# 42/42 [==============================] - 18s 440ms/step - loss: 0.0263 - accuracy: 0.9925 - val_loss: 0.0134 - val_accuracy: 0.9956
# Epoch 48/50
# 42/42 [==============================] - 19s 442ms/step - loss: 0.0233 - accuracy: 0.9918 - val_loss: 0.0111 - val_accuracy: 0.9956
# Epoch 49/50
# 42/42 [==============================] - 19s 456ms/step - loss: 0.0284 - accuracy: 0.9910 - val_loss: 0.0123 - val_accuracy: 0.9956
# Epoch 50/50
# 42/42 [==============================] - 19s 442ms/step - loss: 0.0216 - accuracy: 0.9925 - val_loss: 0.0116 - val_accuracy: 0.9956
# 8/8 [==============================] - 1s 120ms/step
# Training time for Fold 5: 1001.94 seconds
# Mengkompilasi model...
# fold 6
# Training head model...
# Epoch 1/50
# 42/42 [==============================] - 20s 452ms/step - loss: 0.0190 - accuracy: 0.9948 - val_loss: 0.0292 - val_accuracy: 0.9912
# Epoch 2/50
# 42/42 [==============================] - 18s 440ms/step - loss: 0.0243 - accuracy: 0.9925 - val_loss: 0.0278 - val_accuracy: 0.9912
# Epoch 3/50
# 42/42 [==============================] - 18s 436ms/step - loss: 0.0252 - accuracy: 0.9896 - val_loss: 0.0292 - val_accuracy: 0.9912
# Epoch 4/50
# 42/42 [==============================] - 18s 433ms/step - loss: 0.0213 - accuracy: 0.9933 - val_loss: 0.0274 - val_accuracy: 0.9912
# Epoch 5/50
# 42/42 [==============================] - 19s 465ms/step - loss: 0.0325 - accuracy: 0.9888 - val_loss: 0.0268 - val_accuracy: 0.9912
# Epoch 6/50
# 42/42 [==============================] - 18s 441ms/step - loss: 0.0248 - accuracy: 0.9918 - val_loss: 0.0296 - val_accuracy: 0.9912
# Epoch 7/50
# 42/42 [==============================] - 18s 439ms/step - loss: 0.0277 - accuracy: 0.9910 - val_loss: 0.0273 - val_accuracy: 0.9912
# Epoch 8/50
# 42/42 [==============================] - 19s 453ms/step - loss: 0.0137 - accuracy: 0.9970 - val_loss: 0.0308 - val_accuracy: 0.9912
# Epoch 9/50
# 42/42 [==============================] - 19s 441ms/step - loss: 0.0178 - accuracy: 0.9948 - val_loss: 0.0271 - val_accuracy: 0.9912
# Epoch 10/50
# 42/42 [==============================] - 19s 450ms/step - loss: 0.0224 - accuracy: 0.9925 - val_loss: 0.0285 - val_accuracy: 0.9912
# Epoch 11/50
# 42/42 [==============================] - 19s 445ms/step - loss: 0.0234 - accuracy: 0.9940 - val_loss: 0.0282 - val_accuracy: 0.9912
# Epoch 12/50
# 42/42 [==============================] - 19s 443ms/step - loss: 0.0307 - accuracy: 0.9881 - val_loss: 0.0288 - val_accuracy: 0.9912
# Epoch 13/50
# 42/42 [==============================] - 19s 451ms/step - loss: 0.0197 - accuracy: 0.9933 - val_loss: 0.0279 - val_accuracy: 0.9912
# Epoch 14/50
# 42/42 [==============================] - 19s 442ms/step - loss: 0.0171 - accuracy: 0.9948 - val_loss: 0.0276 - val_accuracy: 0.9912
# Epoch 15/50
# 42/42 [==============================] - 20s 466ms/step - loss: 0.0218 - accuracy: 0.9910 - val_loss: 0.0294 - val_accuracy: 0.9912
# Epoch 16/50
# 42/42 [==============================] - 18s 437ms/step - loss: 0.0262 - accuracy: 0.9873 - val_loss: 0.0284 - val_accuracy: 0.9912
# Epoch 17/50
# 42/42 [==============================] - 19s 444ms/step - loss: 0.0206 - accuracy: 0.9933 - val_loss: 0.0317 - val_accuracy: 0.9912
# Epoch 18/50
# 42/42 [==============================] - 20s 471ms/step - loss: 0.0229 - accuracy: 0.9918 - val_loss: 0.0306 - val_accuracy: 0.9912
# Epoch 19/50
# 42/42 [==============================] - 18s 440ms/step - loss: 0.0213 - accuracy: 0.9940 - val_loss: 0.0310 - val_accuracy: 0.9912
# Epoch 20/50
# 42/42 [==============================] - 18s 437ms/step - loss: 0.0126 - accuracy: 0.9955 - val_loss: 0.0283 - val_accuracy: 0.9912
# Epoch 21/50
# 42/42 [==============================] - 19s 453ms/step - loss: 0.0301 - accuracy: 0.9910 - val_loss: 0.0299 - val_accuracy: 0.9912
# Epoch 22/50
# 42/42 [==============================] - 18s 434ms/step - loss: 0.0262 - accuracy: 0.9918 - val_loss: 0.0294 - val_accuracy: 0.9912
# Epoch 23/50
# 42/42 [==============================] - 19s 451ms/step - loss: 0.0255 - accuracy: 0.9910 - val_loss: 0.0296 - val_accuracy: 0.9912
# Epoch 24/50
# 42/42 [==============================] - 18s 435ms/step - loss: 0.0167 - accuracy: 0.9933 - val_loss: 0.0279 - val_accuracy: 0.9912
# Epoch 25/50
# 42/42 [==============================] - 19s 445ms/step - loss: 0.0263 - accuracy: 0.9888 - val_loss: 0.0294 - val_accuracy: 0.9912
# Epoch 26/50
# 42/42 [==============================] - 18s 435ms/step - loss: 0.0177 - accuracy: 0.9963 - val_loss: 0.0281 - val_accuracy: 0.9912
# Epoch 27/50
# 42/42 [==============================] - 19s 442ms/step - loss: 0.0241 - accuracy: 0.9933 - val_loss: 0.0279 - val_accuracy: 0.9912
# Epoch 28/50
# 42/42 [==============================] - 19s 464ms/step - loss: 0.0289 - accuracy: 0.9918 - val_loss: 0.0301 - val_accuracy: 0.9912
# Epoch 29/50
# 42/42 [==============================] - 18s 433ms/step - loss: 0.0272 - accuracy: 0.9918 - val_loss: 0.0290 - val_accuracy: 0.9912
# Epoch 30/50
# 42/42 [==============================] - 18s 435ms/step - loss: 0.0172 - accuracy: 0.9955 - val_loss: 0.0304 - val_accuracy: 0.9912
# Epoch 31/50
# 42/42 [==============================] - 20s 467ms/step - loss: 0.0194 - accuracy: 0.9925 - val_loss: 0.0314 - val_accuracy: 0.9912
# Epoch 32/50
# 42/42 [==============================] - 18s 434ms/step - loss: 0.0204 - accuracy: 0.9933 - val_loss: 0.0292 - val_accuracy: 0.9912
# Epoch 33/50
# 42/42 [==============================] - 19s 460ms/step - loss: 0.0223 - accuracy: 0.9910 - val_loss: 0.0286 - val_accuracy: 0.9912
# Epoch 34/50
# 42/42 [==============================] - 19s 438ms/step - loss: 0.0176 - accuracy: 0.9948 - val_loss: 0.0276 - val_accuracy: 0.9912
# Epoch 35/50
# 42/42 [==============================] - 19s 442ms/step - loss: 0.0207 - accuracy: 0.9933 - val_loss: 0.0304 - val_accuracy: 0.9912
# Epoch 36/50
# 42/42 [==============================] - 19s 460ms/step - loss: 0.0237 - accuracy: 0.9940 - val_loss: 0.0325 - val_accuracy: 0.9912
# Epoch 37/50
# 42/42 [==============================] - 18s 436ms/step - loss: 0.0173 - accuracy: 0.9933 - val_loss: 0.0308 - val_accuracy: 0.9912
# Epoch 38/50
# 42/42 [==============================] - 19s 446ms/step - loss: 0.0178 - accuracy: 0.9925 - val_loss: 0.0313 - val_accuracy: 0.9912
# Epoch 39/50
# 42/42 [==============================] - 20s 457ms/step - loss: 0.0248 - accuracy: 0.9918 - val_loss: 0.0305 - val_accuracy: 0.9912
# Epoch 40/50
# 42/42 [==============================] - 18s 436ms/step - loss: 0.0168 - accuracy: 0.9955 - val_loss: 0.0320 - val_accuracy: 0.9912
# Epoch 41/50
# 42/42 [==============================] - 19s 450ms/step - loss: 0.0182 - accuracy: 0.9940 - val_loss: 0.0317 - val_accuracy: 0.9912
# Epoch 42/50
# 42/42 [==============================] - 18s 435ms/step - loss: 0.0150 - accuracy: 0.9948 - val_loss: 0.0313 - val_accuracy: 0.9912
# Epoch 43/50
# 42/42 [==============================] - 19s 447ms/step - loss: 0.0182 - accuracy: 0.9933 - val_loss: 0.0281 - val_accuracy: 0.9912
# Epoch 44/50
# 42/42 [==============================] - 20s 475ms/step - loss: 0.0173 - accuracy: 0.9948 - val_loss: 0.0281 - val_accuracy: 0.9868
# Epoch 45/50
# 42/42 [==============================] - 19s 445ms/step - loss: 0.0148 - accuracy: 0.9955 - val_loss: 0.0305 - val_accuracy: 0.9912
# Epoch 46/50
# 42/42 [==============================] - 18s 439ms/step - loss: 0.0209 - accuracy: 0.9918 - val_loss: 0.0298 - val_accuracy: 0.9912
# Epoch 47/50
# 42/42 [==============================] - 19s 452ms/step - loss: 0.0227 - accuracy: 0.9933 - val_loss: 0.0299 - val_accuracy: 0.9912
# Epoch 48/50
# 42/42 [==============================] - 19s 451ms/step - loss: 0.0198 - accuracy: 0.9955 - val_loss: 0.0301 - val_accuracy: 0.9912
# Epoch 49/50
# 42/42 [==============================] - 21s 499ms/step - loss: 0.0112 - accuracy: 0.9970 - val_loss: 0.0331 - val_accuracy: 0.9912
# Epoch 50/50
# 42/42 [==============================] - 18s 440ms/step - loss: 0.0129 - accuracy: 0.9955 - val_loss: 0.0335 - val_accuracy: 0.9912
# 8/8 [==============================] - 1s 118ms/step
# Training time for Fold 6: 980.84 seconds
# Mengkompilasi model...
# fold 7
# Training head model...
# Epoch 1/50
# 42/42 [==============================] - 21s 467ms/step - loss: 0.0219 - accuracy: 0.9933 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 2/50
# 42/42 [==============================] - 19s 447ms/step - loss: 0.0236 - accuracy: 0.9933 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 3/50
# 42/42 [==============================] - 19s 441ms/step - loss: 0.0157 - accuracy: 0.9940 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 4/50
# 42/42 [==============================] - 18s 439ms/step - loss: 0.0192 - accuracy: 0.9925 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 5/50
# 42/42 [==============================] - 20s 486ms/step - loss: 0.0224 - accuracy: 0.9896 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 6/50
# 42/42 [==============================] - 19s 445ms/step - loss: 0.0138 - accuracy: 0.9948 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 7/50
# 42/42 [==============================] - 19s 447ms/step - loss: 0.0184 - accuracy: 0.9918 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 8/50
# 42/42 [==============================] - 20s 486ms/step - loss: 0.0226 - accuracy: 0.9918 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 9/50
# 42/42 [==============================] - 19s 448ms/step - loss: 0.0163 - accuracy: 0.9963 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 10/50
# 42/42 [==============================] - 19s 448ms/step - loss: 0.0216 - accuracy: 0.9933 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 11/50
# 42/42 [==============================] - 19s 443ms/step - loss: 0.0226 - accuracy: 0.9933 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 12/50
# 42/42 [==============================] - 19s 445ms/step - loss: 0.0152 - accuracy: 0.9955 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 13/50
# 42/42 [==============================] - 21s 482ms/step - loss: 0.0246 - accuracy: 0.9903 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 14/50
# 42/42 [==============================] - 19s 449ms/step - loss: 0.0169 - accuracy: 0.9933 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 15/50
# 42/42 [==============================] - 20s 478ms/step - loss: 0.0203 - accuracy: 0.9925 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 16/50
# 42/42 [==============================] - 19s 448ms/step - loss: 0.0274 - accuracy: 0.9918 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 17/50
# 42/42 [==============================] - 19s 441ms/step - loss: 0.0211 - accuracy: 0.9925 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 18/50
# 42/42 [==============================] - 20s 481ms/step - loss: 0.0172 - accuracy: 0.9933 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 19/50
# 42/42 [==============================] - 19s 442ms/step - loss: 0.0219 - accuracy: 0.9925 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 20/50
# 42/42 [==============================] - 19s 449ms/step - loss: 0.0231 - accuracy: 0.9910 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 21/50
# 42/42 [==============================] - 19s 449ms/step - loss: 0.0174 - accuracy: 0.9933 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 22/50
# 42/42 [==============================] - 19s 445ms/step - loss: 0.0251 - accuracy: 0.9918 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 23/50
# 42/42 [==============================] - 20s 468ms/step - loss: 0.0255 - accuracy: 0.9925 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 24/50
# 42/42 [==============================] - 18s 440ms/step - loss: 0.0194 - accuracy: 0.9940 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 25/50
# 42/42 [==============================] - 20s 485ms/step - loss: 0.0222 - accuracy: 0.9910 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 26/50
# 42/42 [==============================] - 19s 442ms/step - loss: 0.0200 - accuracy: 0.9925 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 27/50
# 42/42 [==============================] - 18s 438ms/step - loss: 0.0182 - accuracy: 0.9925 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 28/50
# 42/42 [==============================] - 19s 449ms/step - loss: 0.0149 - accuracy: 0.9940 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 29/50
# 42/42 [==============================] - 18s 437ms/step - loss: 0.0199 - accuracy: 0.9888 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 30/50
# 42/42 [==============================] - 19s 449ms/step - loss: 0.0199 - accuracy: 0.9948 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 31/50
# 42/42 [==============================] - 18s 437ms/step - loss: 0.0184 - accuracy: 0.9925 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 32/50
# 42/42 [==============================] - 19s 441ms/step - loss: 0.0246 - accuracy: 0.9925 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 33/50
# 42/42 [==============================] - 20s 470ms/step - loss: 0.0189 - accuracy: 0.9948 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 34/50
# 42/42 [==============================] - 20s 458ms/step - loss: 0.0203 - accuracy: 0.9918 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 35/50
# 42/42 [==============================] - 20s 481ms/step - loss: 0.0171 - accuracy: 0.9925 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 36/50
# 42/42 [==============================] - 19s 442ms/step - loss: 0.0121 - accuracy: 0.9963 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 37/50
# 42/42 [==============================] - 19s 441ms/step - loss: 0.0192 - accuracy: 0.9925 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 38/50
# 42/42 [==============================] - 20s 467ms/step - loss: 0.0139 - accuracy: 0.9948 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 39/50
# 42/42 [==============================] - 19s 443ms/step - loss: 0.0148 - accuracy: 0.9940 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 40/50
# 42/42 [==============================] - 19s 443ms/step - loss: 0.0183 - accuracy: 0.9933 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 41/50
# 42/42 [==============================] - 19s 442ms/step - loss: 0.0246 - accuracy: 0.9925 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 42/50
# 42/42 [==============================] - 18s 439ms/step - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 43/50
# 42/42 [==============================] - 20s 456ms/step - loss: 0.0141 - accuracy: 0.9948 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 44/50
# 42/42 [==============================] - 19s 443ms/step - loss: 0.0227 - accuracy: 0.9910 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 45/50
# 42/42 [==============================] - 20s 466ms/step - loss: 0.0182 - accuracy: 0.9948 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 46/50
# 42/42 [==============================] - 19s 441ms/step - loss: 0.0138 - accuracy: 0.9948 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 47/50
# 42/42 [==============================] - 18s 436ms/step - loss: 0.0210 - accuracy: 0.9933 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 48/50
# 42/42 [==============================] - 20s 463ms/step - loss: 0.0270 - accuracy: 0.9903 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 49/50
# 42/42 [==============================] - 19s 443ms/step - loss: 0.0216 - accuracy: 0.9918 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 50/50
# 42/42 [==============================] - 19s 464ms/step - loss: 0.0180 - accuracy: 0.9940 - val_loss: 0.0039 - val_accuracy: 1.0000
# 8/8 [==============================] - 1s 119ms/step
# Training time for Fold 7: 991.53 seconds
# Fold 1 - Accuracy: 0.9825, F1 Score: 0.9825, Precision: 0.9828, Recall: 0.9823
# Training time for Fold 1: 980.81 seconds
# Fold 2 - Accuracy: 0.9782, F1 Score: 0.9782, Precision: 0.9790, Recall: 0.9783
# Training time for Fold 2: 971.00 seconds
# Fold 3 - Accuracy: 0.9956, F1 Score: 0.9956, Precision: 0.9954, Recall: 0.9959
# Training time for Fold 3: 999.07 seconds
# Fold 4 - Accuracy: 1.0000, F1 Score: 1.0000, Precision: 1.0000, Recall: 1.0000
# Training time for Fold 4: 952.50 seconds
# Fold 5 - Accuracy: 0.9956, F1 Score: 0.9956, Precision: 0.9955, Recall: 0.9957
# Training time for Fold 5: 1001.94 seconds
# Fold 6 - Accuracy: 0.9912, F1 Score: 0.9912, Precision: 0.9906, Recall: 0.9919
# Training time for Fold 6: 980.84 seconds
# Fold 7 - Accuracy: 1.0000, F1 Score: 1.0000, Precision: 1.0000, Recall: 1.0000
# Training time for Fold 7: 991.53 seconds

# %% [markdown]
# ## Evaluasi Jaringan

# %%
from sklearn.metrics import confusion_matrix
# Hitung confusion matrix
conf_matrix = confusion_matrix(test_labels.argmax(axis=1), predictions.argmax(axis=1))

# Tampilkan confusion matrix
print(f"Confusion Matrix for Fold {fold}:\n{conf_matrix}")

# Atau, Anda juga dapat menggunakan library seaborn untuk tampilan yang lebih baik
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=lb.classes_, yticklabels=lb.classes_)
plt.title(f'Confusion Matrix - Fold {fold}')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Confusion Matrix for Fold 7:
# [[111   0]
#  [  0 117]]

# %%
# Convert model to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TensorFlow Lite model to a file
tflite_model_filename = 'model.tflite'
with open(tflite_model_filename, 'wb') as f:
    f.write(tflite_model)

print(f"TensorFlow Lite model saved to {tflite_model_filename}")
# Out:
# TensorFlow Lite model saved to model.tflite
